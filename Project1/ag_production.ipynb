# %% [markdown]
# ## Lecture III How is agricultural production increasing?

# %% [markdown]
# We&rsquo;ve seen that growth in food production is typically greater than
# population growth.  But where is this growth coming from?
#
# Food (and crops in particular) are the classical example of
# production.  The &ldquo;classical&rdquo; economists in the 18th century, when
# most income came from agriculture, thought there were three main
# &ldquo;factors&rdquo; of production:
#
# -   Land
# -   Labor
# -   Capital
#
# Thus one might write the technical relationship between &ldquo;factors&rdquo; (or
# inputs) and output as
# $$
#     \text{Crop output} = F(\mbox{Land},\mbox{Labor},\mbox{Capital}).
#  $$

# %% [markdown]
# ### Functional forms

# %% [markdown]
# We have good reason to think that $F$ displays constant returns to
# scale; i.e., is homogeneous of degree one.  Write it as
# $F(x_1,x_2,\dots,x_n)$ (thus abstracting from the classical factors
# of production).
#
# Observationally, it&rsquo;s also often the case the cost share for
# different factors of production remains constant, even when prices
# change.  If we combine these facts (linearly homogeneous, constant
# cost shares) with an assumption that farmers operating this
# production function are profit maximizing price-takers and a
# technical assumption that $F$ is continuously differentiable, then
# one can prove that $F$ is &ldquo;Cobb-Douglas&rdquo;, or
# $$
#       F(x_1,x_2,\dots,x_n) = A\prod_{i=1}^nx_i^{\alpha_i},
#   $$
# where $\sum_{i=1}^n\alpha_i=1$.  This is a result first established
# by the economist Paul Douglas and the mathematician Charles Cobb in 1928.
#
# If we observe output at time $t$ for country $j$, say $y^j_t$ and inputs $x^j_{it}$, we can take the
# logarithm of the Cobb-Douglas production function, obtaining
# $$
#      \log y^j_t = \log A^j_t + \sum_{i=1}^n\alpha^j_i\log(x^j_{it}).
#   $$
# Note that we&rsquo;ve allowed the cost-share parameters $\alpha$ to vary
# across both inputs and also countries, but *not* over time.

# %% [markdown]
# ### Total Factor Productivity

# %% [markdown]
# The term $A$ is sometimes called &ldquo;Total Factor Productivity&rdquo; (TFP),
# because increases in $A$ increase productivity of all factors.  If
# we take differences in log output over time we get
# $$
#       \Delta\log y^j_t = \Delta\log A^j_t + \sum_{i=1}^n\alpha^j_i\Delta\log(x^j_{it}).
#    $$
# Recall that changes in logs approximate percent changes or growth
# rates, so we can use this equation to decompose output growth into
# growth in input use and TFP growth.

# %% [markdown]
# ### Data on Food Production

# %% [markdown]
# What’s happened to food production over recent decades?
# See
# [https://www.ers.usda.gov/data-products/international-agricultural-productivity/](https://www.ers.usda.gov/data-products/international-agricultural-productivity/).
#
# Data on TFP, output, factor use, and factor shares can be found at
# [https://docs.google.com/spreadsheets/d/1DLn9owcS7ggojJGWlI9vKSz0hqozn6cbcqNGWgzMZ8k](https://docs.google.com/spreadsheets/d/1DLn9owcS7ggojJGWlI9vKSz0hqozn6cbcqNGWgzMZ8k),
# which is publicly readable.

# %% [markdown]
# ### Reading Sheets

# %% [markdown]
# I&rsquo;ve written a python package `eep153_tools` which includes tools to
# handle authentication as well as reading google sheets as pandas
# DataFrames.  First we have to deal with authentication, by decrypting
# credentials to access particular files (you should only have to do
# this part once):

# %%
#!pip install eep153_tools
#!pip install python_gnupg

from eep153_tools.sheets import decrypt_credentials
decrypt_credentials('../students.json.gpg')
# Out:
# Input secret passphrase for ../students.json.gpg to create google drive credentials: noodle octopus

# %% [markdown]
# To check that this worked, the following gives a list of
# emails for &ldquo;service<sub>accounts</sub>&rdquo; that now have credentials&#x2013;you can
# then &ldquo;share&rdquo; google sheets with these.

# %%
# !ls ~/.eep153.service_accounts/
# Out:
# instructors@eep153.iam.gserviceaccount.com
# students@eep153.iam.gserviceaccount.com

# %% [markdown]
# With those credentials established

# %%
from eep153_tools.sheets import read_sheets

#### Read a bunch of google worksheets into a dictionary of dataframes
data = read_sheets('https://docs.google.com/spreadsheets/d/1J_Yoo2eBgABBy8Hnvh2Vf7GYowELZBYTVwt-3NtjUsc/edit#gid=1532023339')['Data']

data.keys()
# Out:
# Key available for instructors@eep153.iam.gserviceaccount.com.
# Key available for students@eep153.iam.gserviceaccount.com.
# /home/ligon/Teaching/EEP153/eep153_tools/sheets.py:134: UserWarning: Unable to open https://docs.google.com/spreadsheets/d/1J_Yoo2eBgABBy8Hnvh2Vf7GYowELZBYTVwt-3NtjUsc/edit#gid=1532023339 using credentials for instructors@eep153.iam.gserviceaccount.com.
#   warnings.warn(f'Unable to open {key} using credentials for {service_acct}.')
# Index(['Order', 'FAO', 'ISO3', 'Level', 'Country/Territory', 'Region',
#        'Subregion', 'Income', 'Year', 'TFP_Index', 'Outall_Index',
#        'Input_Index', 'Land_Index', 'Labor_Index', 'Capital_Index',
#        'Materials_Index', 'Outall_Q', 'Outcrop_Q', 'Outanim_Q', 'Outfish_Q',
#        'Land_Q', 'Labor_Q', 'Capital_Q', 'Machinery_Q', 'Livestock_Q',
#        'Fertilizer_Q', 'Feed_Q', 'Cropland_Q', 'Pasture_Q', 'IrrigArea_Q'],
#       dtype='object')

# %% [markdown]
# This gives a dictionary of dataframes, but these dataframes need to be
# tidied up some.  For example, look at `Outall_Index`:

# %%
data.tail()
# Out:
#        Order  FAO ISO3   Level Country/Territory                   Region  \
# 13331    243  NaN       Region                    G20 (19 countries 2021)
# 13332    243  NaN       Region                    G20 (19 countries 2021)
# 13333    243  NaN       Region                    G20 (19 countries 2021)
# 13334    243  NaN       Region                    G20 (19 countries 2021)
# 13335    243  NaN       Region                    G20 (19 countries 2021)
#
#       Subregion Income  Year  TFP_Index  ...        Land_Q      Labor_Q  \
# 13331                   2016   101.6680  ...  1.243977e+06  481284.9228
# 13332                   2017   104.6567  ...  1.249681e+06  472232.4342
# 13333                   2018   106.0598  ...  1.249286e+06  461882.1800
# 13334                   2019   105.8433  ...  1.253635e+06  448426.2779
# 13335                   2020   106.8674  ...  1.252543e+06  436136.9191
#
#           Capital_Q   Machinery_Q   Livestock_Q  Fertilizer_Q        Feed_Q  \
# 13331  3.995280e+06  2.236022e+06  1.191882e+06  1.592013e+08  2.885579e+09
# 13332  4.104074e+06  2.276166e+06  1.204587e+06  1.583811e+08  2.991555e+09
# 13333  4.216871e+06  2.308464e+06  1.208838e+06  1.568847e+08  3.009592e+09
# 13334  4.323576e+06  2.354034e+06  1.189710e+06  1.622938e+08  3.126475e+09
# 13335  4.487207e+06  2.276589e+06  1.204267e+06  1.688653e+08  3.188809e+09
#
#         Cropland_Q     Pasture_Q  IrrigArea_Q
# 13331  885980.5888  1.628312e+06  214470.0666
# 13332  887794.2355  1.657323e+06  215797.8895
# 13333  887969.7809  1.643916e+06  216816.8026
# 13334  887471.6416  1.648720e+06  219884.9000
# 13335  886764.9694  1.642048e+06  220368.7000
#
# [5 rows x 30 columns]

# %% [markdown]
# We really just want selected columns, and an index that depends on country and year:

# %%
import pandas as pd

Data = {'Level':'Level','Country':'Country/Territory','WDI Code':'ISO3','Year':'Year','Output':'Outall_Index','TFP':'TFP_Index','Land':'Land_Index','Labor':'Labor_Index','Capital':'Capital_Index','Materials':'Materials_Index'}


df = data.rename(columns={v:k for k,v in Data.items()})
df = df[Data.keys()].set_index(['WDI Code','Level','Country','Year'])

# Deal with some duplicate indices
df = df.loc[~df.index.duplicated(),:]
df
# Out:
#                                  Output       TFP     Land     Labor  Capital  \
# WDI Code Level   Country Year
# NGA      Country Nigeria 1961   19.5115   86.5804  40.8615   57.7794   8.6628
#                          1962   20.3487   87.6861  41.4735   58.8275   8.9988
#                          1963   21.2221   87.0572  44.9049   59.9037   9.3708
#                          1964   21.8586   87.3097  46.1668   61.0112   9.7532
#                          1965   22.7648   86.1499  49.1628   62.1489  10.4784
# ...                                 ...       ...      ...       ...      ...
#          Region          2016   98.9888   99.7940  99.6151  100.9345  99.1207
#                          2017   99.6899  101.1619  99.7266   99.1944  98.8609
#                          2018   99.2904  101.3774  98.9821   97.9636  99.4202
#                          2019   99.1303  100.2704  99.2921   97.4115  99.3946
#                          2020  100.3743  102.9362  98.8359   94.4130  99.8714
#
#                                Materials
# WDI Code Level   Country Year
# NGA      Country Nigeria 1961     8.2788
#                          1962     8.8999
#                          1963     9.4456
#                          1964     9.4536
#                          1965     9.9916
# ...                                  ...
#          Region          2016    98.2452
#                          2017    97.8932
#                          2018    97.2640
#                          2019    99.3756
#                          2020    98.1530
#
# [12976 rows x 6 columns]

# %% [markdown]
# ### Visualizing data on ag production

# %% [markdown]
# Plot growth in output for all countries for 1961 on:

# %%
import cufflinks as cf
cf.go_offline()

df['Output'].unstack().T.iplot(title="Index of Agricultural Output",
                               yTitle='Value of Output Index',
                               xTitle='Year')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="bce47f90-ae34-409c-ae50-ce152f90b172" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("bce47f90-ae34-409c-ae50-ce152f90b172")) {                    Plotly.newPlot(                        "bce47f90-ae34-409c-ae50-ce152f90b172",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"('', 'Country', 'Lesser Antilles')","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[134.0179,136.3789,138.3357,132.9428,146.6431,147.6414,144.2737,136.6122,138.9402,130.734,131.9873,126.9979,124.2401,127.1151,119.8511,128.6904,130.9655,138.5017,123.2579,111.1666,121.279,125.8794,121.373,129.4141,129.5031,141.5536,134.7261,145.9484,136.6239,133.0033,122.0507,126.7516,124.6934,108.4878,109.6373,121.4163,126.0569,114.3073,118.7747,117.6957,108.2189,115.4437,112.0715,108.9627,101.3701,95.4749,95.7407,97.7313,101.6498,97.0832,101.3357,95.8039,94.1417,99.2578,100.0,98.0366,96.672,96.9744,98.5689,97.933],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"('', 'Country', 'Micronesia')","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[25.5504,23.7477,21.7565,23.3691,30.0999,29.2543,33.12,25.1085,25.6355,26.9546,30.6218,23.771,30.4701,36.6071,23.3441,29.5228,30.0415,34.5709,32.0001,29.5394,36.5863,34.4397,29.0699,41.0006,41.5249,45.6045,47.8098,50.9896,37.5796,34.3488,50.8111,51.2858,48.6551,50.2517,74.3106,80.5464,78.733,77.121,78.1812,73.136,72.3922,73.1012,77.5981,82.8358,84.0232,95.4396,92.4965,94.004,94.2606,95.8112,94.7604,98.5644,97.6748,101.0355,100.0,100.4126,100.9677,92.0567,93.3909,94.6426],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"('', 'Country', 'Polynesia')","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[93.2949,97.3188,99.6286,101.0585,95.0774,96.2311,93.7703,95.3786,104.8856,97.1348,103.3011,101.1776,97.1629,100.8916,108.1468,105.8672,103.7561,96.325,103.098,110.6959,106.0866,106.5875,96.7232,94.1888,100.3518,102.3886,97.2011,93.0597,91.0314,85.8047,78.0453,77.4797,82.943,79.7893,82.3484,84.0072,86.0284,83.6607,84.1737,86.6581,88.0997,91.8729,93.612,92.8888,98.8669,98.3963,104.7426,103.3855,104.3009,106.077,109.8915,108.8071,108.3603,99.3631,100.0,95.1425,94.24,95.1856,89.3536,93.478],"type":"scatter"},{"line":{"color":"rgba(128, 0, 128, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"('', 'Income', '')","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[27.1146,28.6463,28.9868,29.891,29.7246,30.3297,32.4511,32.9615,34.6402,35.5328,35.8889,36.765,36.3576,38.5759,39.9704,40.857,41.2356,42.3039,41.3619,43.2679,44.807,45.0815,45.7599,44.0334,46.1792,47.6309,46.9561,50.6541,49.7562,50.8652,52.1456,52.4367,53.4404,54.1365,54.4829,57.8303,58.1028,62.1748,62.5424,62.677,66.2376 ...

# %% [markdown]
# Compare world growth in outputs, inputs, and TFP:

# %%
import numpy as np

world = df.xs('World',level='Level').replace(0,np.nan).dropna(how='any')

# Drop unnecessary index levels
world = world.droplevel(['WDI Code','Country'])

# Put in log differences
dworld = np.log(world).diff()
dworld['Inputs'] = dworld['Output'] - dworld['TFP']

dworld.mean()
# Out:
# Output       0.023150
# TFP          0.009915
# Land         0.004572
# Labor        0.004167
# Capital      0.020977
# Materials    0.024321
# Inputs       0.013235
# dtype: float64

# %% [markdown]
# And a graph of growth rates:

# %%
dworld[['Output','Inputs','TFP']].iplot(title="Growth rates of output, inputs, & TFP",
                                           xTitle="Year")
# Out:
# <div>                            <div id="8bd0a700-702c-40ee-b74b-887e3328f079" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8bd0a700-702c-40ee-b74b-887e3328f079")) {                    Plotly.newPlot(                        "8bd0a700-702c-40ee-b74b-887e3328f079",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Output","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":["",0.031697479515870874,0.025029842377968237,0.03282140116867671,0.02170978190029027,0.035626677003499196,0.035210721673640144,0.029109009070002134,0.0055407132471398945,0.030702603197568124,0.024710830773046144,-0.004169261842418948,0.05430321859402243,0.007678105984272765,0.01960443965886638,0.023308522102526208,0.024339117540897792,0.0446242482379402,0.010937798373846341,0.002228704422410299,0.03266835287689984,0.032615829391179574,0.005001749371905007,0.05001687732474602,0.01822536630196181,0.018373030962604897,0.013646076482635383,0.01149213919333203,0.034660348004674546,0.02544698073809082,-0.007391000642309464,0.024997277467769585,0.011346433649934262,0.026486136257246606,0.024523925166066718,0.03899931919267896,0.020779997214308565,0.01701660838936725,0.03233314507593121,0.022396929303418744,0.015895037836346937,0.015606855239352235,0.026983251526120355,0.047019269461943125,0.019975632300727852,0.02344088723261528,0.028601625855758428,0.038775847277035425,0.008720746341971619,0.02558590803958083,0.036729547378032024,0.012602526388683977,0.03986959960838554,0.021512398517381293,0.013751114689749322,0.015528801617626264,0.029706480008925062,0.01277510251694114,0.009906174993741246,0.014205216545057908],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Inputs","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":["",0.028659033136266387,0.02409270663800811,0.028000575197498545,0.03403169583723953,0.02797490694412641,0.024182052617212513,0.02544109142587958,0.02276250835911009,0.028341776377835082,0.021593898946410395,0.019817791068196478,0.02277699509489617,-0.0009374523493685949,0.020663250830595725,0.019198880153033837,0.0191111640395758,0.024841906103111988,0.017676509699428244,0.012485814855015764,0.006156715423088155,0.015450159908806604,0.016419697152576518,0.017170549574331506,0.008132334765698968,0.017345755715767464,0.013472144834256294,0.007799008604461477,0.010787174188591209,0.016876200386521045,-0.00037165081262280353,-0.00050976894898902,-0.006436383172246707,0.005172451635972131,0.0047027776787702535,0.01495502357447176,0.010695205280774722,0.010842891325876458,0.012969063510153589,0.009881926291519072,0.011948045319906342,0.009558489370331102,0.011701993201310934,0.01255632993706346,0.004979719236758662,0.004329290242709227,0.006437124049658571,0.0028779445856086383,0.006218085548761465,0.013939490279264888,0.01084794991266591,0.00750940833130187,0.01188516453745514,0.00584419815609305,0.008973721096089626,0.008957440384604887,0.008218220463990455,0.004821070342950762,0.008832157341785773,0.00820274681725941],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"TFP","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,20 ...

# %% [markdown]
# That&rsquo;s the overall picture for the world.  Now &ldquo;drill down&rdquo; and
# consider just production in the US:

# %%
select = df.xs('USA',level='WDI Code').dropna(how='any')

# Drop unnecessary index levels
select = select.droplevel(['Level','Country'])

dselect = np.log(select).diff()
dselect['Inputs'] = dselect['Output'] - dselect['TFP']

dselect.mean()
# Out:
# Output       0.015012
# TFP          0.011983
# Land        -0.000656
# Labor       -0.013495
# Capital      0.008603
# Materials    0.009642
# Inputs       0.003029
# dtype: float64

# %% [markdown]
# And here a graph of growth in indices of inputs & outputs since 1961:

# %%
select = df.xs('USA',level='WDI Code').dropna(how='any').droplevel(['Level','Country'])

select = select/select.loc[1961,:]
select.iplot()
# Out:
# <div>                            <div id="b637365c-0015-4025-838c-1161cf378c5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b637365c-0015-4025-838c-1161cf378c5f")) {                    Plotly.newPlot(                        "b637365c-0015-4025-838c-1161cf378c5f",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Output","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[1.0,1.004927771787212,1.0427921488821905,1.0538948306796003,1.0928802814840495,1.0959350947847561,1.1426600062582026,1.1653223537145134,1.1761166276842174,1.1611622247685254,1.2552513748911005,1.2526332850836415,1.2703070796480098,1.2434350779011158,1.3278690369796742,1.3659427712131684,1.422611021190094,1.4227145741833382,1.4936708860759493,1.4278066800685252,1.5589565460124217,1.5645889283841006,1.345511315415664,1.5375323321709886,1.6093598398980677,1.5417892606541397,1.542489368934552,1.4315683551057252,1.5573919953536222,1.6210973465671057,1.596051029114149,1.7275925955107525,1.5901417550431431,1.8199438562684453,1.6882604672941377,1.8052258243155934,1.8653000673094458,1.8710022353939628,1.900039845390879,1.9438405103811873,1.9221146421681294,1.8844483664515317,1.9489573789386716,2.0733222726730403,2.0213049027839998,1.9876456776755504,2.096250256068543,2.1120691013626223,2.1513426996265337,2.1506943678427435,2.130456511119565,2.123714310798551,2.2194805691812785,2.285799507898167,2.2511520270498426,2.43729528586254,2.3828331648721233,2.4091198670919844,2.345108359202822,2.4246573183826823],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"TFP","text":"","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[1.0